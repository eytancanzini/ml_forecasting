# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf

# %matplotlib inline
sns.set(style='whitegrid')
RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
def drop_columns(data):
    return data.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'])

data = yf.Ticker('MSFT')
df = drop_columns(data.history(start='2010-01-01'))
df.head()
# Out:
#             Close
# Date
# 2010-01-04  24.17
# 2010-01-05  24.18
# 2010-01-06  24.03
# 2010-01-07  23.78
# 2010-01-08  23.94

# %%
samples = np.arange(0, len(df), 1)
values = df['Close'].to_numpy()
plt.figure(figsize=(10,5))
plt.title('Microsoft Stock Price')
plt.plot(samples, values)
plt.xlabel('Samples elapsed')
plt.ylabel('Stock Price ($)')
plt.show()
# Out:
# &lt;Figure size 720x360 with 1 Axes&gt;

# %%
df = pd.DataFrame(dict(price=values), index=samples, columns=['price'])

train_size = int(len(df)*0.7)
val_size = int(len(df)*0.2)
test_size = int(len(df)*0.1)

val_set = train_size + val_size
test_size = train_size + val_size + test_size
train, val, test = df.iloc[0:train_size], df.iloc[train_size:val_set], df.iloc[val_set:len(df)]
len(train), len(val), len(test)
# Out:
# (1898, 542, 272)

# %%
TIME_STEPS = 10

def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i+time_steps)].values
        Xs.append(v)
        ys.append(y.iloc[i+time_steps])
    return np.array(Xs), np.array(ys)

X_train, y_train = create_dataset(train, train.price, TIME_STEPS)
X_val, y_val = create_dataset(val, val.price, TIME_STEPS)
X_test, y_test = create_dataset(test, test.price, TIME_STEPS)

def generate_model():
    model = tf.keras.Sequential([
        tf.keras.layers.LSTM(50, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
        tf.keras.layers.LSTM(50, activation='relu'),
        tf.keras.layers.Dense(1)
    ])
    model.compile(loss='mean_squared_error', optimizer='Adam')
    return model

model = generate_model()
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    verbose=1,
    shuffle=False,
    validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/50
# 118/118 [==============================] - 1s 10ms/step - loss: 34.7309 - val_loss: 56.0728
# Epoch 2/50
# 118/118 [==============================] - 1s 7ms/step - loss: 3.4354 - val_loss: 33.6492
# Epoch 3/50
# 118/118 [==============================] - 1s 7ms/step - loss: 4.3039 - val_loss: 28.4537
# Epoch 4/50
# 118/118 [==============================] - 1s 7ms/step - loss: 2.7299 - val_loss: 26.5611
# Epoch 5/50
# 118/118 [==============================] - 1s 7ms/step - loss: 2.7686 - val_loss: 18.7240
# Epoch 6/50
# 118/118 [==============================] - 1s 7ms/step - loss: 2.7286 - val_loss: 14.8917
# Epoch 7/50
# 118/118 [==============================] - 1s 7ms/step - loss: 2.8838 - val_loss: 15.1780
# Epoch 8/50
# 118/118 [==============================] - 1s 7ms/step - loss: 2.8646 - val_loss: 17.4450
# Epoch 9/50
# 118/118 [==============================] - 1s 7ms/step - loss: 2.6502 - val_loss: 19.6629
# Epoch 10/50
# 118/118 [==============================] - 1s 7ms/step - loss: 2.5790 - val_loss: 20.8725
# Epoch 11/50
# 118/118 [==============================] - 1s 7ms/step - loss: 2.5668 - val_loss: 21.2929
# Epoch 12/50
# 118/118 [==============================] - 1s 7ms/step - loss: 2.3696 - val_loss: 20.9439
# Epoch 13/50
# 118/118 [==============================] - 1s 7ms/step - loss: 2.2964 - val_loss: 16.9209
# Epoch 14/50
# 118/118 [==============================] - 1s 7ms/step - loss: 2.1943 - val_loss: 18.5255
# Epoch 15/50
# 118/118 [==============================] - 1s 7ms/step - loss: 2.2316 - val_loss: 15.6132
# Epoch 16/50
# 118/118 [==============================] - 1s 7ms/step - loss: 2.2209 - val_loss: 20.4722
# Epoch 17/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.9890 - val_loss: 20.2871
# Epoch 18/50
# 118/118 [==============================] - 1s 7ms/step - loss: 2.1911 - val_loss: 18.0128
# Epoch 19/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.6972 - val_loss: 15.7305
# Epoch 20/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.8576 - val_loss: 22.8314
# Epoch 21/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.6958 - val_loss: 19.8818
# Epoch 22/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.9197 - val_loss: 27.7105
# Epoch 23/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.6425 - val_loss: 20.7882
# Epoch 24/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.8341 - val_loss: 35.0907
# Epoch 25/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.5305 - val_loss: 18.5217
# Epoch 26/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.7530 - val_loss: 35.1375
# Epoch 27/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.4967 - val_loss: 17.4050
# Epoch 28/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.7283 - val_loss: 31.5975
# Epoch 29/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.5116 - val_loss: 16.2873
# Epoch 30/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.6685 - val_loss: 31.7881
# Epoch 31/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.3936 - val_loss: 17.9925
# Epoch 32/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.5853 - val_loss: 23.8825
# Epoch 33/50
# 118/118 [==============================] - 1s 8ms/step - loss: 1.4968 - val_loss: 21.1059
# Epoch 34/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.5799 - val_loss: 21.3333
# Epoch 35/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.3870 - val_loss: 15.9990
# Epoch 36/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.3671 - val_loss: 15.5062
# Epoch 37/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.2790 - val_loss: 21.4119
# Epoch 38/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.2751 - val_loss: 28.8247
# Epoch 39/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.2193 - val_loss: 9.6720
# Epoch 40/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.3161 - val_loss: 8.8241
# Epoch 41/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.0876 - val_loss: 8.1685
# Epoch 42/50
# 118/118 [==============================] - 1s 7ms/step - loss: 0.9755 - val_loss: 7.2983
# Epoch 43/50
# 118/118 [==============================] - 1s 7ms/step - loss: 0.9599 - val_loss: 7.0520
# Epoch 44/50
# 118/118 [==============================] - 1s 7ms/step - loss: 0.9425 - val_loss: 5.9520
# Epoch 45/50
# 118/118 [==============================] - 1s 7ms/step - loss: 0.9080 - val_loss: 6.3139
# Epoch 46/50
# 118/118 [==============================] - 1s 7ms/step - loss: 0.9802 - val_loss: 4.9805
# Epoch 47/50
# 118/118 [==============================] - 1s 7ms/step - loss: 0.9198 - val_loss: 6.5554
# Epoch 48/50
# 118/118 [==============================] - 1s 7ms/step - loss: 0.8068 - val_loss: 8.2155
# Epoch 49/50
# 118/118 [==============================] - 1s 7ms/step - loss: 0.8629 - val_loss: 11.7657
# Epoch 50/50
# 118/118 [==============================] - 1s 7ms/step - loss: 0.8812 - val_loss: 10.4246

# %%
plt.figure(figsize=(15,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.show()
# Out:
# &lt;Figure size 1080x720 with 1 Axes&gt;

# %%
y_pred = model.predict(X_test)
plt.figure(figsize=(15,10))
plt.plot(np.arange(0, len(y_train)), y_train, 'g')
plt.plot(np.arange(len(y_train), (len(y_train)+len(y_val))), y_val, 'g')
plt.plot(np.arange((len(y_train)+len(y_val)), (len(y_train)+len(y_val)+len(y_test))), y_pred, 'r')
plt.plot(np.arange((len(y_train)+len(y_val)), (len(y_train)+len(y_val)+len(y_test))), y_test, 'b')
plt.xlabel('Samples')
plt.ylabel('Stock Price ($)')
plt.legend(['Train', 'Validation', 'Test Predicted', 'Actual Predicted'])
plt.savefig('Stacked LSTM Example.png')
plt.show()
# Out:
# &lt;Figure size 1080x720 with 1 Axes&gt;
